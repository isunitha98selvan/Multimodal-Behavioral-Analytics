# %%
import pandas as pd
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from mlxtend.preprocessing import standardize
from mlxtend.classifier import MultiLayerPerceptron as MLP
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings("ignore")

# %%
x_data = "/Users/anumehaagrawal/Documents/Course_Work/Emotion-Analysis-in-Multimodal-data/Combined/final - three_features_merged.csv"
y_data = "/Users/anumehaagrawal/Documents/Course_Work/Emotion-Analysis-in-Multimodal-data/Combined/y-output - Sheet1.csv"

# %%
x_df = pd.read_csv(x_data)
y_df = pd.read_csv(y_data)
y_df = y_df.astype(int, errors='ignore')
x_df = x_df.drop(x_df.columns[0], axis=1)
y_df = y_df.drop(y_df.columns[0], axis=1)
x_df = x_df.abs()
y_df = y_df.abs()
x_df = x_df.fillna(0)
#X_train, X_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.25, random_state=42)

# %%
from sklearn.model_selection import KFold 
from sklearn.neural_network import MLPClassifier
kf = RepeatedKFold(n_splits=9, n_repeats=3) 
clf = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(5, 2), random_state=1)


for train_index, test_index in kf.split(x_df):
    print("Fold index:")
    X_train, X_test = x_df.loc[train_index], x_df.loc[val_index]
    y_train, y_test = y_df.loc[train_index], y_df.loc[val_index]
    X_train_std = (X_train - X_train.mean(axis=0)) / X_train.std(axis=0)
    X_test_std = (X_test - X_test.mean(axis=0)) / X_test.std(axis=0)
   
    for i in range(len(y_train.columns)):
        y = y_train[y_train.columns[i:i+1]]
        clf.fit(X_train, y)
        y_pred = clf.predict(X_test)
        y_predict = pd.DataFrame(y_pred)
        print(accuracy_score(y_test[y_test.columns[i:i+1]],y_predict))
# Out:
# Fold index:
# 0.4642857142857143
# 0.39285714285714285
# 0.35714285714285715
# 0.5357142857142857
# 0.42857142857142855
# 0.39285714285714285
# 0.5714285714285714
# 0.8928571428571429
# 0.21428571428571427
# 0.5714285714285714
# 0.6428571428571429
# 0.32142857142857145
# 0.5
# 0.5
# 0.6428571428571429
# 0.6785714285714286
# 0.5714285714285714
# 0.35714285714285715
# 0.03571428571428571
# Fold index:
# 0.4642857142857143
# 0.35714285714285715
# 0.5714285714285714
# 0.5357142857142857
# 0.42857142857142855
# 0.39285714285714285
# 0.5714285714285714
# 0.8928571428571429
# 0.21428571428571427
# 0.5714285714285714
# 0.6428571428571429
# 0.32142857142857145
# 0.5
# 0.5
# 0.6428571428571429
# 0.6785714285714286
# 0.5714285714285714
# 0.21428571428571427
# 0.03571428571428571
# Fold index:
# 0.4642857142857143
# 0.35714285714285715
# 0.5714285714285714
# 0.5357142857142857
# 0.42857142857142855
# 0.39285714285714285
# 0.5714285714285714
# 0.8928571428571429
# 0.21428571428571427
# ...

# %%
#print(y_train.head())

# %%
X_train_std = (X_train - X_train.mean(axis=0)) / X_train.std(axis=0)
X_test_std = (X_test - X_test.mean(axis=0)) / X_test.std(axis=0)

# %%
print(X_train_std)
# Out:
#      0.0003103610031  58.89807156   196.992  142.1601663  74.30483534  \
# 117         0.937572     1.017044  2.982844    -0.710532     0.409689
# 101        -0.691794    -0.564400 -0.283748    -1.111119    -0.527682
# 0           2.311504     1.650370  0.504630    -1.734029     0.039952
# 78         -0.412646    -0.135354 -0.491893     0.923007    -0.033328
# 62         -0.542444    -0.318440 -0.700039     1.265780    -1.561407
# ..               ...          ...       ...          ...          ...
# 71          1.078525     1.096825 -1.002795     0.510463     0.397595
# 106         0.131183     0.445433 -0.567583     0.335478    -0.618038
# 14         -0.791202    -0.753990 -0.725319     0.298304    -1.003158
# 92          0.144320     0.456878  0.801029    -0.905434     0.171733
# 102        -1.030516    -1.359541  0.246076    -1.690211    -0.415862
#
#      599.939292  0.07841212505  0.002936686887  3.097412401  0.1709953368  \
# ...

# %%
# nn1 = MLP(hidden_layers=[10], 
#           l2=0.00, 
#           l1=0.0, 
#           epochs=5, 
#           eta=0.005, 
#           momentum=0.1,
#           decrease_const=0.0,
#           minibatches=len(y_train), 
#           random_seed=3,
#           print_progress=3)

# print(y_train)
from sklearn.neural_network import MLPClassifier

clf = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(5, 2), random_state=1)
for i in range(len(y_train.columns)):
    y = y_train[y_train.columns[i:i+1]]
    clf.fit(X_train, y)
    y_pred = clf.predict(X_test)
    y_predict = pd.DataFrame(y_pred)
    print(accuracy_score(y_test[y_test.columns[i:i+1]],y_predict))

# plt.plot(range(len(nn1.cost_)), nn1.cost_)
# plt.ylabel('Cost')
# plt.xlabel('Epochs')
# plt.show()
# Out:
# 0.14285714285714285
# 0.37142857142857144
# 0.5428571428571428
# 0.6
# 0.4
# 0.5714285714285714
# 0.34285714285714286
# 0.8857142857142857
# 0.3142857142857143
# 0.4857142857142857
# 0.7142857142857143
# 0.45714285714285713
# 0.42857142857142855
# 0.7714285714285715
# 0.8285714285714286
# 0.6285714285714286
# 0.5714285714285714
# 0.42857142857142855
# 0.08571428571428572

# %%
print('Train Accuracy: %.2f%%' % (100 * clf.score(X_train_std, y_train[y_train.columns[0:1]])))
print('Test Accuracy: %.2f%%' % (100 * clf.score(X_test_std, y_test[y_test.columns[0:1]])))
# Out:
# Train Accuracy: 90.20%
# Test Accuracy: 45.71%
